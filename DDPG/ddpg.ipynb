# %% [markdown]
# #Implementation of DDPG - Deep Deterministic Policy Gradient
#
# Algorithm and hyperparameter details can be found here:
#     http://arxiv.org/pdf/1509.02971v2.pdf
#
# The algorithm is tested on the Pendulum-v0 OpenAI gym task and developed with Tensorflow 2.0.
#
# Author: Krishna Chaitanya Kosaraju
#
# *I followed closely the code of  https://github.com/pemami4911/deep-rl/blob/master/ddpg/ddpg.py (which uses TF 1.x and TFlearn)*

# %% [markdown]
# ## Importing Necessary Packages

# %%
# %tensorflow_version 2.x
import tensorflow as tf
import numpy as np
import gym
import argparse
from tensorflow import keras
from tensorflow.keras import Input, Model, Sequential, layers
print(tf.__version__)
tf.test.gpu_device_name()
# Out:
# 2.1.0
# '/device:GPU:0'

# %% [markdown]
# ##     Actor and Critic DNNs

# %%
class ActorNetwork(object):
  def __init__(self, state_dim, action_dim, action_bound, learning_rate, tau, batch_size):
    self.state_dim = state_dim
    self.action_dim = action_dim
    self.action_bound = action_bound
    self.learning_rate = learning_rate
    self.tau  = tau
    self.batch_size = batch_size
    self.optimizer = tf.keras.optimizers.SGD(self.learning_rate)

    #actor network
    self.inputs, self.out, self.scaled_out = self.create_actor_network()
    self.actor_model = keras.Model(inputs=self.inputs, outputs=self.scaled_out, name='actor_network')
    self.network_params = self.actor_model.trainable_variables

    #target actor network
    self.target_inputs, self.target_out, self.target_scaled_out = self.create_actor_network()
    self.target_actor_model = keras.Model(inputs=self.target_inputs, outputs=self.target_scaled_out, name='target_actor_network')
    self.target_network_params = self.target_actor_model.trainable_variables


  def create_actor_network(self):
    #placeholders for inputs
    inputs = Input(shape = (self.state_dim,), batch_size = None, name = "actor_input_state")

    #first layer
    net = layers.Dense(400, name = 'actor_dense_1')(inputs)
    net = layers.BatchNormalization()(net)
    net = layers.Activation(activation=tf.nn.relu)(net)

    #second layer
    net = layers.Dense(300, name = 'actor_dense_2')(net)
    net = layers.BatchNormalization()(net)
    net = layers.Activation(activation=tf.nn.relu)(net)
    
    #Output Layer
    w_init = tf.random_uniform_initializer(minval=-0.03, maxval=0.03, seed=None)
    out = layers.Dense(self.action_dim, activation='tanh', name = 'actor_dense_3', kernel_initializer = w_init)(net)
    scaled_out = tf.multiply(out, self.action_bound, name = "actions_scaling")
    return inputs, out, scaled_out
  
  def update_target_network(self):
    """
    Ops to update taret network params using a list comprehension
    """
    self.update_target_network_params = [self.target_network_params[i].assign(tf.multiply(self.network_params[i], self.tau) + tf.multiply(self.target_network_params[i], 1-self.tau)) for i in range(len(self.target_network_params))]
    #for i in range(len(self.target_network_params)):
    #  self.target_network_params[i] = tf.multiply(self.network_params[i], self.tau) + tf.multiply(self.target_network_params[i], 1-self.tau)


  def train(self, inputs, a_gradient):
    """
    inputs      : states
    a_gradient  : Gradient of Q network w.r.t actions

    With gradient tape to update the actor network.
    """
    with tf.GradientTape() as self.tape:
      self.prediction = self.actor_model(inputs)
    self.unnormalized_actor_gradients = self.tape.gradient(self.prediction, self.network_params, output_gradients = -a_gradient)
    self.actor_gradients = list(map(lambda x: tf.math.divide(x, self.batch_size), self.unnormalized_actor_gradients))
    self.optimizer.apply_gradients(zip(self.actor_gradients, self.network_params))
    


  def predict(self, inputs):
    """
    inputs: States

    Provided state variable, we return the actions predicted by actor network
    """
    return self.actor_model(inputs)



  def predict_target(self, inputs):
    """
    inputs: States

    Provided state variable, we return the actions predicted by TARGET actor network
    """
    return self.target_actor_model(inputs)

# %%
class CriticNetwork(object):
  def __init__(self, state_dim, action_dim, action_bound, learning_rate, tau, gamma):
    self.state_dim = state_dim
    self.action_dim = action_dim
    self.action_bound = action_bound
    self.learning_rate = learning_rate
    self.tau  = tau
    self.gamma = gamma
    self.optimizer = tf.keras.optimizers.Adam(self.learning_rate)

    #Critic Network and parameters
    self.inputs_state, self.inputs_action, self.out = self.create_critic_network()
    self.critic_model = keras.Model(inputs=[self.inputs_state, self.inputs_action], outputs=self.out, name='critic_network')
    self.network_params = self.critic_model.trainable_variables

    #Target Critic Network and parameters
    self.target_inputs_state, self.target_inputs_action, self.target_out = self.create_critic_network()
    self.target_critic_model = keras.Model(inputs=[self.target_inputs_state, self.target_inputs_action], outputs=self.target_out, name='target_critic_network')
    self.target_network_params = self.target_critic_model.trainable_variables

    #gradients of Q function with respect to actions



  def create_critic_network(self):
    """
    Actions are skipped in the first layer.
    """
    #placeholders for states and actions
    inputs_state = Input(shape = (self.state_dim,), batch_size = None, name = "critic_input_state")
    inputs_action = Input(shape = (self.action_dim,), batch_size = None, name = "critic_input_action")
    
    #first hidden layer with states as inputs
    net_state = layers.Dense(400, name = 'critic_dense_1')(inputs_state)
    net_state = layers.BatchNormalization()(net_state)
    net_state = layers.Activation(activation=tf.nn.relu)(net_state)

    # second hidden layer with actions and output of first layer as input 
    net_state = layers.Dense(300, name = 'critic_dense_2_state')(net_state)
    net_action = layers.Dense(300, name = 'critic_dense_2_action')(inputs_action)
    net = layers.Add()([net_state, net_action])
    net = layers.BatchNormalization()(net)
    net = layers.Activation(activation=tf.nn.relu)(net)

    #output layer
    w_init = tf.random_uniform_initializer(minval=-0.03, maxval=0.03, seed=None)
    out = layers.Dense(1, name = 'Q_val', kernel_initializer = w_init)(net)
    return inputs_state, inputs_action, out



  def update_target_network(self):
    """
    Ops to update the params of Critic target netowrk
    """
    self.update_target_network_params = [self.target_network_params[i].assign(tf.multiply(self.network_params[i], self.tau) + tf.multiply(self.target_network_params[i], 1-self.tau)) for i in range(len(self.target_network_params))]



  def train(self, input_state, input_actions, predicted_q_val):
    """
    Updates the params of Q network and returns Q values
    input_state : states
    input_actions : actions
    predicted_q_val : Q value from belman equations using Target Q network
    """
    with tf.GradientTape() as self.tape:
      self.prediction = self.critic_model([input_state, input_actions])
      self.loss = tf.keras.losses.MSE(self.prediction, predicted_q_val)
    self.gradients = self.tape.gradient(self.loss, self.network_params)
    self.optimizer.apply_gradients(zip(self.gradients, self.network_params))
    return self.critic_model([input_state, input_actions])



  def action_gradient(self, input_state, input_actions):
    """
    Computes the gradient of Q network w.r.t actions
    input_state : states
    input_actions : actions
    """
    var = tf.constant(input_actions)
    with tf.GradientTape(watch_accessed_variables=False) as self.tape:
      self.tape.watch(var)
      self.prediction = self.critic_model([input_state, var])
    return self.tape.gradient(self.prediction, var)



  def predict(self, inputs_state, inputs_actions):
    return self.critic_model([inputs_state, inputs_actions])



  def predict_target(self, inputs_state, inputs_actions):
    return self.target_critic_model([inputs_state, inputs_actions])

# %% [markdown]
# ## Ornstein Uhlenbeck Action Noise

# %%
# Taken from https://github.com/openai/baselines/blob/master/baselines/ddpg/noise.py, which is
# based on http://math.stackexchange.com/questions/1287634/implementing-ornstein-uhlenbeck-in-matlab
class OrnsteinUhlenbeckActionNoise:
    def __init__(self, mu, sigma=0.3, theta=.15, dt=1e-2, x0=None):
        self.theta = theta
        self.mu = mu
        self.sigma = sigma
        self.dt = dt
        self.x0 = x0
        self.reset()

    def __call__(self):
        x = self.x_prev + self.theta * (self.mu - self.x_prev) * self.dt + \
                self.sigma * np.sqrt(self.dt) * np.random.normal(size=self.mu.shape)
        self.x_prev = x
        return x

    def reset(self):
        self.x_prev = self.x0 if self.x0 is not None else np.zeros_like(self.mu)

    def __repr__(self):
        return 'OrnsteinUhlenbeckActionNoise(mu={}, sigma={})'.format(self.mu, self.sigma)

# %% [markdown]
# ## Replay buffer

# %%
# Taken from https://github.com/pemami4911/deep-rl/blob/master/ddpg/replay_buffer.py
from collections import deque
import random
import numpy as np

class ReplayBuffer(object):

    def __init__(self, buffer_size, random_seed=123):
        """
        The right side of the deque contains the most recent experiences 
        """
        self.buffer_size = buffer_size
        self.count = 0
        self.buffer = deque()
        random.seed(random_seed)

    def add(self, s, a, r, t, s2):
        experience = (s, a, r, t, s2)
        if self.count < self.buffer_size: 
            self.buffer.append(experience)
            self.count += 1
        else:
            self.buffer.popleft()
            self.buffer.append(experience)

    def size(self):
        return self.count

    def sample_batch(self, batch_size):
        batch = []

        if self.count < batch_size:
            batch = random.sample(self.buffer, self.count)
        else:
            batch = random.sample(self.buffer, batch_size)

        s_batch = np.array([_[0] for _ in batch])
        a_batch = np.array([_[1] for _ in batch])
        r_batch = np.array([_[2] for _ in batch])
        t_batch = np.array([_[3] for _ in batch])
        s2_batch = np.array([_[4] for _ in batch])

        return s_batch, a_batch, r_batch, t_batch, s2_batch

    def clear(self):
        self.buffer.clear()
        self.count = 0

# %% [markdown]
# # Agent

# %%
def train(env, args, actor, critic, actor_noise, reward_result):
  writer = tf.summary.create_file_writer(logdir = args['summary_dir'])
  actor.update_target_network()
  critic.update_target_network()
  replay_buffer = ReplayBuffer(int(args['buffer_size']), int(args['random_seed']))

  paths = list()

  for i in range(args['max_episode_len']):
    s = env.reset()
    ep_reward = 0
    ep_ave_max_q = 0
    obs, actions, rewards = [], [], []
    for j in range(args['max_episode_len']):
      a = actor.predict(np.reshape(s,(1,actor.state_dim))) + actor_noise()
      #print(j,a)
      s2, r, terminal, info = env.step(a[0])
      replay_buffer.add(np.reshape(s, (actor.state_dim,)), np.reshape(a, (actor.action_dim,)), r, terminal, np.reshape(s2, (actor.state_dim,)))
      if replay_buffer.size() > args['mini_batch_size']:
        s_batch, a_batch, r_batch, t_batch, s2_batch = replay_buffer.sample_batch(args['mini_batch_size'])
        target_q = np.array(critic.predict_target(s2_batch, actor.predict_target(s2_batch)))
        #print("target_q", i,j, target_q[0])
        y = []
        for k in range(args['mini_batch_size']):
          if t_batch[k]:
            y.append(r_batch[k])
          else:
            y.append(r_batch[k] + critic.gamma * np.array(target_q[k]))
        temp_targets = np.reshape(y, (args['mini_batch_size'],1))
        predicted_q_value = critic.train(s_batch, a_batch, temp_targets.astype('float32'))
        ep_ave_max_q += np.amax(predicted_q_value)

        a_outs = actor.predict(s_batch)
        grads = critic.action_gradient(s_batch, a_outs)
        actor.train(s_batch, grads)
        actor.update_target_network()
        critic.update_target_network()

      s = s2
      ep_reward += r
      obs.append(s)
      actions.append(a[0])
      rewards.append(r)

      if terminal:
        with writer.as_default():
          tf.summary.scalar("Reward", ep_reward, step = i)
          tf.summary.scalar("Qmax Value", ep_ave_max_q / float(j), step = i)
          writer.flush()
        print('| Reward: {:.4f} | Episode: {:d} | Qmax: {:.4f}'.format((ep_reward), i, (ep_ave_max_q / float(j))))
        reward_result[i] = ep_reward
        path = {
            "Observation":np.concatenate(obs).reshape((200,3)), 
            "Action":np.concatenate(action), 
            "Reward":np.asarray(rewards)
            }
        paths.append(path)
        break

# %%
args = {
    'summary_dir' : '/content/sample_data',
    'buffer_size' : 1000000,
    'random_seed' : 1754,
    'max_episodes': 600,
    'max_episode_len' : 200,
    'mini_batch_size': 64
}

tf.keras.backend.set_floatx('float32')
env = gym.make('Pendulum-v0')
state = env.reset()

state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
action_bound = env.action_space.high

actor = ActorNetwork(state_dim = state_dim, action_dim=action_dim, action_bound=action_bound, learning_rate=0.0001, tau=0.001, batch_size=args['mini_batch_size'])
#action = actor.actor_model(np.reshape(state, (1,actor.state_dim)))
critic = CriticNetwork(state_dim = state_dim, action_dim=action_dim, action_bound=action_bound, learning_rate=0.001, tau=0.001, gamma=.99)
actor_noise = OrnsteinUhlenbeckActionNoise(mu=np.zeros(action_dim))
reward_result = np.zeros(2500)


train(env, args, actor, critic, actor_noise, reward_result)
# Out:
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# WARNING:tensorflow:Layer actor_dense_1 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer actor_dense_1 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer critic_dense_1 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer critic_dense_1 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# | Reward: -1079.8721 | Episode: 0 | Qmax: -0.6415
# | Reward: -1604.8582 | Episode: 1 | Qmax: -0.0619
# | Reward: -1373.7561 | Episode: 2 | Qmax: -0.3986
# | Reward: -1475.8394 | Episode: 3 | Qmax: -0.4404
# | Reward: -1445.9850 | Episode: 4 | Qmax: -0.5414
# | Reward: -1497.1422 | Episode: 5 | Qmax: -0.8292
# | Reward: -1197.9527 | Episode: 6 | Qmax: -0.9118
# | Reward: -1507.9011 | Episode: 7 | Qmax: -1.0973
# | Reward: -1438.5670 | Episode: 8 | Qmax: -1.2759
# | Reward: -1337.5840 | Episode: 9 | Qmax: -1.5156
# | Reward: -1565.7092 | Episode: 10 | Qmax: -1.5144
# | Reward: -1577.9693 | Episode: 11 | Qmax: -1.7843
# | Reward: -1595.3719 | Episode: 12 | Qmax: -1.7648
# | Reward: -1437.0506 | Episode: 13 | Qmax: -2.3107
# | Reward: -1556.3693 | Episode: 14 | Qmax: -2.3813
# | Reward: -1534.0541 | Episode: 15 | Qmax: -2.6678
# | Reward: -1644.6344 | Episode: 16 | Qmax: -2.9038
# | Reward: -1494.6555 | Episode: 17 | Qmax: -3.4145
# | Reward: -1478.4951 | Episode: 18 | Qmax: -3.7752
# | Reward: -1535.3914 | Episode: 19 | Qmax: -4.3238
# | Reward: -1315.9731 | Episode: 20 | Qmax: -4.4203
# | Reward: -1286.3246 | Episode: 21 | Qmax: -4.6976
# | Reward: -1496.6491 | Episode: 22 | Qmax: -4.3305
# | Reward: -1145.7129 | Episode: 23 | Qmax: -5.1072
# | Reward: -1210.2180 | Episode: 24 | Qmax: -5.3411
# | Reward: -1310.4056 | Episode: 25 | Qmax: -5.5434
# | Reward: -1095.5203 | Episode: 26 | Qmax: -5.7846
# | Reward: -1396.8864 | Episode: 27 | Qmax: -6.0426
# | Reward: -1250.4653 | Episode: 28 | Qmax: -6.9960
# | Reward: -1099.1547 | Episode: 29 | Qmax: -6.9461
# | Reward: -1085.0986 | Episode: 30 | Qmax: -7.1415
# | Reward: -1174.4876 | Episode: 31 | Qmax: -7.7899
# | Reward: -1524.3446 | Episode: 32 | Qmax: -7.9784
# | Reward: -673.8548 | Episode: 33 | Qmax: -6.4250
# | Reward: -821.3226 | Episode: 34 | Qmax: -5.4570
# | Reward: -1264.7850 | Episode: 35 | Qmax: -4.5641
# | Reward: -6.6291 | Episode: 36 | Qmax: -2.0553
# | Reward: -517.5381 | Episode: 37 | Qmax: -0.7925
# | Reward: -1295.0189 | Episode: 38 | Qmax: -0.9004
# | Reward: -821.6878 | Episode: 39 | Qmax: -0.8273
# | Reward: -662.7164 | Episode: 40 | Qmax: -0.8937
# | Reward: -400.9782 | Episode: 41 | Qmax: -0.5234
# | Reward: -690.6891 | Episode: 42 | Qmax: -0.1911
# | Reward: -396.9845 | Episode: 43 | Qmax: -0.1021
# | Reward: -418.0377 | Episode: 44 | Qmax: -0.0531
# | Reward: -269.7597 | Episode: 45 | Qmax: -0.1542
# | Reward: -274.3278 | Episode: 46 | Qmax: -0.0076
# | Reward: -3.2478 | Episode: 47 | Qmax: -0.0145
# | Reward: -1503.8260 | Episode: 48 | Qmax: -0.0356
# | Reward: -1500.8500 | Episode: 49 | Qmax: 0.0220
# | Reward: -132.1038 | Episode: 50 | Qmax: -0.0075
# | Reward: -558.9206 | Episode: 51 | Qmax: 0.0670
# | Reward: -128.9468 | Episode: 52 | Qmax: 0.0442
# | Reward: -402.8893 | Episode: 53 | Qmax: 0.1229
# | Reward: -0.9259 | Episode: 54 | Qmax: 0.0568
# | Reward: -1214.7151 | Episode: 55 | Qmax: 0.1318
# | Reward: -129.4762 | Episode: 56 | Qmax: 0.1730
# | Reward: -129.1468 | Episode: 57 | Qmax: 0.2036
# | Reward: -403.5101 | Episode: 58 | Qmax: 0.2220
# | Reward: -263.7754 | Episode: 59 | Qmax: 0.1835
# | Reward: -264.9093 | Episode: 60 | Qmax: 0.2174
# | Reward: -421.2800 | Episode: 61 | Qmax: 0.2142
# | Reward: -263.4652 | Episode: 62 | Qmax: 0.1864
# | Reward: -132.7079 | Episode: 63 | Qmax: 0.2133
# | Reward: -292.7148 | Episode: 64 | Qmax: 0.2742
# | Reward: -132.8106 | Episode: 65 | Qmax: 0.2324
# | Reward: -1559.5468 | Episode: 66 | Qmax: 0.2645
# | Reward: -132.9517 | Episode: 67 | Qmax: 0.2295
# | Reward: -491.8707 | Episode: 68 | Qmax: 0.2191
# | Reward: -527.3930 | Episode: 69 | Qmax: 0.2795
# | Reward: -127.0112 | Episode: 70 | Qmax: 0.3469
# | Reward: -0.4398 | Episode: 71 | Qmax: 0.2608
# | Reward: -502.6487 | Episode: 72 | Qmax: 0.2187
# | Reward: -293.5840 | Episode: 73 | Qmax: 0.3072
# | Reward: -256.4357 | Episode: 74 | Qmax: 0.3644
# | Reward: -130.2488 | Episode: 75 | Qmax: 0.3515
# | Reward: -381.0336 | Episode: 76 | Qmax: 0.3231
# | Reward: -254.4516 | Episode: 77 | Qmax: 0.3956
# | Reward: -249.7950 | Episode: 78 | Qmax: 0.4028
# | Reward: -284.4788 | Episode: 79 | Qmax: 0.4493
# | Reward: -129.5517 | Episode: 80 | Qmax: 0.4300
# | Reward: -125.4263 | Episode: 81 | Qmax: 0.4740
# | Reward: -118.1691 | Episode: 82 | Qmax: 0.4894
# | Reward: -252.0969 | Episode: 83 | Qmax: 0.4826
# | Reward: -0.6226 | Episode: 84 | Qmax: 0.6695
# | Reward: -0.5198 | Episode: 85 | Qmax: 0.6106
# | Reward: -236.8637 | Episode: 86 | Qmax: 0.6630
# | Reward: -267.9800 | Episode: 87 | Qmax: 0.5732
# | Reward: -251.0781 | Episode: 88 | Qmax: 0.6882
# | Reward: -394.2446 | Episode: 89 | Qmax: 0.6821
# | Reward: -0.9421 | Episode: 90 | Qmax: 0.9086
# | Reward: -115.1063 | Episode: 91 | Qmax: 0.8273
# | Reward: -130.2088 | Episode: 92 | Qmax: 0.9127
# | Reward: -124.9709 | Episode: 93 | Qmax: 0.9363
# | Reward: -469.3423 | Episode: 94 | Qmax: 1.0345
# | Reward: -435.7002 | Episode: 95 | Qmax: 1.0860
# | Reward: -259.7782 | Episode: 96 | Qmax: 1.0568
# | Reward: -253.4248 | Episode: 97 | Qmax: 1.0927
# | Reward: -254.5532 | Episode: 98 | Qmax: 1.2761
# | Reward: -247.9079 | Episode: 99 | Qmax: 1.3537
# | Reward: -118.6708 | Episode: 100 | Qmax: 1.2148
# | Reward: -130.4587 | Episode: 101 | Qmax: 1.4537
# | Reward: -271.7668 | Episode: 102 | Qmax: 1.5375
# | Reward: -116.4435 | Episode: 103 | Qmax: 1.5786
# | Reward: -126.8280 | Episode: 104 | Qmax: 1.7024
# | Reward: -252.2707 | Episode: 105 | Qmax: 1.6528
# | Reward: -226.4392 | Episode: 106 | Qmax: 1.7853
# | Reward: -264.2414 | Episode: 107 | Qmax: 1.7937
# | Reward: -368.0502 | Episode: 108 | Qmax: 1.8914
# | Reward: -126.4977 | Episode: 109 | Qmax: 2.1188
# | Reward: -354.6300 | Episode: 110 | Qmax: 1.9309
# | Reward: -370.7045 | Episode: 111 | Qmax: 2.1245
# | Reward: -233.0521 | Episode: 112 | Qmax: 2.2199
# | Reward: -410.9623 | Episode: 113 | Qmax: 2.4287
# | Reward: -252.1663 | Episode: 114 | Qmax: 2.5545
# | Reward: -306.5887 | Episode: 115 | Qmax: 2.8056
# | Reward: -118.1863 | Episode: 116 | Qmax: 2.6984
# | Reward: -249.8138 | Episode: 117 | Qmax: 2.7827
# | Reward: -129.8724 | Episode: 118 | Qmax: 2.8937
# | Reward: -128.2018 | Episode: 119 | Qmax: 3.1305
# | Reward: -249.9156 | Episode: 120 | Qmax: 3.3119
# | Reward: -128.3509 | Episode: 121 | Qmax: 3.2605
# | Reward: -0.1122 | Episode: 122 | Qmax: 3.4079
# | Reward: -120.0252 | Episode: 123 | Qmax: 3.3252
# | Reward: -253.7025 | Episode: 124 | Qmax: 3.6281
# | Reward: -233.4393 | Episode: 125 | Qmax: 3.6525
# | Reward: -243.2006 | Episode: 126 | Qmax: 3.8358
# | Reward: -243.8547 | Episode: 127 | Qmax: 3.9170
# | Reward: -121.8203 | Episode: 128 | Qmax: 4.0373
# | Reward: -0.8884 | Episode: 129 | Qmax: 4.5194
# | Reward: -125.7567 | Episode: 130 | Qmax: 4.7392
# | Reward: -127.1474 | Episode: 131 | Qmax: 4.5908
# | Reward: -244.5675 | Episode: 132 | Qmax: 4.9770
# | Reward: -404.9935 | Episode: 133 | Qmax: 5.0123
# | Reward: -125.2696 | Episode: 134 | Qmax: 4.9729
# | Reward: -246.8977 | Episode: 135 | Qmax: 5.1611
# | Reward: -125.1656 | Episode: 136 | Qmax: 4.8241
# | Reward: -119.2133 | Episode: 137 | Qmax: 5.3012
# | Reward: -115.8740 | Episode: 138 | Qmax: 5.3546
# | Reward: -242.9649 | Episode: 139 | Qmax: 5.6055
# | Reward: -122.1338 | Episode: 140 | Qmax: 5.1630
# | Reward: -123.0806 | Episode: 141 | Qmax: 5.5128
# | Reward: -121.1536 | Episode: 142 | Qmax: 5.5879
# | Reward: -0.9427 | Episode: 143 | Qmax: 5.6767
# | Reward: -372.4275 | Episode: 144 | Qmax: 5.7796
# | Reward: -377.1459 | Episode: 145 | Qmax: 5.4866
# | Reward: -231.3608 | Episode: 146 | Qmax: 5.8124
# | Reward: -129.0679 | Episode: 147 | Qmax: 5.9053
# | Reward: -121.3458 | Episode: 148 | Qmax: 6.0314
# | Reward: -1.0102 | Episode: 149 | Qmax: 6.3209
# | Reward: -0.4791 | Episode: 150 | Qmax: 5.9705
# | Reward: -130.5796 | Episode: 151 | Qmax: 5.7107
# | Reward: -128.5789 | Episode: 152 | Qmax: 6.5433
# | Reward: -126.6944 | Episode: 153 | Qmax: 6.7477
# | Reward: -126.1709 | Episode: 154 | Qmax: 7.0072
# | Reward: -126.2974 | Episode: 155 | Qmax: 6.8877
# | Reward: -118.4425 | Episode: 156 | Qmax: 7.3846
# | Reward: -125.5429 | Episode: 157 | Qmax: 7.3220
# | Reward: -118.1547 | Episode: 158 | Qmax: 7.2585
# | Reward: -243.6874 | Episode: 159 | Qmax: 7.3664
# | Reward: -120.3695 | Episode: 160 | Qmax: 7.4322
# | Reward: -129.1558 | Episode: 161 | Qmax: 6.9461
# | Reward: -366.6456 | Episode: 162 | Qmax: 7.4223
# | Reward: -129.0420 | Episode: 163 | Qmax: 7.2411
# | Reward: -242.3032 | Episode: 164 | Qmax: 8.0685
# | Reward: -235.3619 | Episode: 165 | Qmax: 8.1227
# | Reward: -246.5804 | Episode: 166 | Qmax: 8.6452
# | Reward: -117.9807 | Episode: 167 | Qmax: 7.9247
# | Reward: -1.6184 | Episode: 168 | Qmax: 8.7065
# | Reward: -246.6727 | Episode: 169 | Qmax: 8.2672
# | Reward: -1.2921 | Episode: 170 | Qmax: 9.7397
# | Reward: -2.1642 | Episode: 171 | Qmax: 9.2433
# | Reward: -370.6938 | Episode: 172 | Qmax: 8.8573
# | Reward: -335.8205 | Episode: 173 | Qmax: 9.6152
# | Reward: -126.8955 | Episode: 174 | Qmax: 9.4175
# | Reward: -1.8123 | Episode: 175 | Qmax: 10.1241
# | Reward: -0.5132 | Episode: 176 | Qmax: 10.0870
# | Reward: -126.8359 | Episode: 177 | Qmax: 9.6138
# | Reward: -130.9689 | Episode: 178 | Qmax: 10.3038
# | Reward: -258.2041 | Episode: 179 | Qmax: 10.3931
# | Reward: -129.0987 | Episode: 180 | Qmax: 10.0066
# | Reward: -122.0937 | Episode: 181 | Qmax: 10.3363
# | Reward: -119.2916 | Episode: 182 | Qmax: 11.5369
# | Reward: -1513.6679 | Episode: 183 | Qmax: 11.5174
# | Reward: -336.1464 | Episode: 184 | Qmax: 11.1877
# | Reward: -280.2580 | Episode: 185 | Qmax: 11.9264
# | Reward: -418.9481 | Episode: 186 | Qmax: 12.6165
# | Reward: -497.6080 | Episode: 187 | Qmax: 12.9403
# | Reward: -610.4367 | Episode: 188 | Qmax: 13.4836
# | Reward: -635.7637 | Episode: 189 | Qmax: 14.6508
# | Reward: -379.4454 | Episode: 190 | Qmax: 14.9832
# | Reward: -243.7737 | Episode: 191 | Qmax: 15.7321
# | Reward: -123.8268 | Episode: 192 | Qmax: 16.8258
# | Reward: -1.7994 | Episode: 193 | Qmax: 16.4074
# | Reward: -247.2467 | Episode: 194 | Qmax: 16.7158
# | Reward: -2.7880 | Episode: 195 | Qmax: 17.4258
# | Reward: -132.9958 | Episode: 196 | Qmax: 18.0368
# | Reward: -134.3976 | Episode: 197 | Qmax: 19.2257
# | Reward: -283.9024 | Episode: 198 | Qmax: 19.4156
# | Reward: -374.6807 | Episode: 199 | Qmax: 20.0134
